# %% [markdown]
# <a href="https://colab.research.google.com/github/amishakapse/Hotel-Booking-Analysis/blob/main/EDA_Hotel_Booking_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hotel Booking Analysis.

# %% [markdown]
# **Have you ever wondered when the best time of year to book a hotel room is ? Or the optimal length of stay in order to get the best daily rate ? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests ? This hotel booking dataset can help you explore those questions!
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things.
# Explore and analyze the data to discover important factors that govern the bookings.**

# %% [markdown]
# ![indian-hotels (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Importing libraries required for EDA capstone project :-

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import plotly 
import plotly.express as px

# %%
from google.colab import drive     
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Location of csv file
 
filepath = ("/content/drive/MyDrive/EDA Capstone Project/Hotel Bookings.csv")

# %%
# Reading csv file

df= pd.read_csv(filepath)

# %% [markdown]
# ## Exploring the data of csv file :-

# %%
# CSV file (Dataframe)

df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# Identify the shape of Data. (Rows and column numbers)

print(f' We have total {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
#  We have total 119390 rows and 32 columns.

# %%
# Presenting info about Datatype
 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# Columns present in csv file

df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Determine the minimum, maximum ,mean values etc. NAN values for mean,25% ,50%,75%,max indicates those are categorical columns.

df.describe() # (including overall data)
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Check for the First 10 rows and their respective columns.(mentioning the index no for first 10 value is not necessary)

df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
# Check for the Last 10 rows and their respective columns.(Mentioning the index no for last 10 value is not necessary)

df.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %%
# Creating a copy of dataset.

DF_1 = df.copy()

# %%
# Checking the null values.

DF_1.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Checking the null values.  

DF_1.isna().sum().sort_values(ascending=False)[:4].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#     Columns  Null values
# 0   company       112593
# 1     agent        16340
# 2   country          488
# 3  children            4

# %%
# So we have null values in columns - Company, Agent, Country, Children.

# For company, agent and childrens fill the Missing values with 0.

# For country missing values with objects is 'Not known'. (Assuming while collecting data country was not found so user selected the 'Not known' option.)

# As the count of missing values in Children column is only 4, so we can replace with '0' considering no childrens.

# %%
# Replacing all null values with '0'.

null_columns=['agent','children','company']
for col in null_columns:
  DF_1[col].fillna(0,inplace=True)


# Replacing NAN values with 'Not known'.

DF_1['country'].fillna('Not known',inplace=True)

# %%
# Handled Null Values.

DF_1.isna().sum().sort_values(ascending=False)[:4].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#                      Columns  Null values
# 0                      hotel            0
# 1                is_canceled            0
# 2         reservation_status            0
# 3  total_of_special_requests            0

# %%
# Performing this operation for the purpose of eliminating duplicate data from the raw dataframe.

DF_1[DF_1.duplicated()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 5       Resort Hotel            0         14               2015
# 22      Resort Hotel            0         72               2015
# 43      Resort Hotel            0         70               2015
# 138     Resort Hotel            1          5               2015
# 200     Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119349    City Hotel            0        186               2017
# 119352    City Hotel            0         63               2017
# 119353    City Hotel            0         63               2017
# 119354    City Hotel            0         63               2017
# 119373    City Hotel            0        175               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 5                    July                        27
# 22                   July                        27
# ...

# %%
# Checking duplicate values of data.

# Checking for the duplicate values rows.(True indicates Duplicate values.)

DF_1.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
# Presented the shape of duplicate data.

print(f' Total duplicate data {DF_1.duplicated().value_counts()[1]} Rows and {DF_1.shape[1]} Columns.')
# Out:
#  Total duplicate data 31994 Rows and 32 Columns.

# %%
# Dropped the duplicates rows to Extract the dataframe.

DF_1= DF_1.drop_duplicates()

# %%
# The shape of data after removing the null and duplicate values.

DF_1.shape
# Out:
# (87396, 32)

# %%
print(f'We have total sorted final data for analyse purpose is {DF_1.shape[0]} rows and {DF_1.shape[1]} columns.')
# Out:
# We have total sorted final data for analyse purpose is 87396 rows and 32 columns.

# %%
# Extracting the Unique values from the data frame. 

DF_1['hotel'].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
DF_1['arrival_date_year'].unique()
# Out:
# array([2015, 2016, 2017])

# %%
DF_1['arrival_date_month'].unique()
DF_1['arrival_date_month'].unique()[6:]
DF_1['arrival_date_month'].unique()[0:6]
DF_1_final_arrival_month = np.concatenate((DF_1['arrival_date_month'].unique()[6:],DF_1['arrival_date_month'].unique()[0:6]))
DF_1_final_arrival_month
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
DF_1['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Undefined'], dtype=object)

# %%
DF_1['market_segment'].unique()
# Out:
# array(['Direct', 'Corporate', 'Online TA', 'Offline TA/TO',
#        'Complementary', 'Groups', 'Undefined', 'Aviation'], dtype=object)

# %%
DF_1['distribution_channel'].unique()
# Out:
# array(['Direct', 'Corporate', 'TA/TO', 'Undefined', 'GDS'], dtype=object)

# %%
a=DF_1['adults'].unique()
b=DF_1['babies'].unique()
c=DF_1['children'].unique()
print(a)
print(b)
print(c)
# Out:
# [ 2  1  3  4 40 26 50 27 55  0 20  6  5 10]
# [ 0  1  2 10  9]
# [ 0.  1.  2. 10.  3.]

# %% [markdown]
# All the Data cleaning process is completed, Further then visualizing and Analysing process is started.

# %% [markdown]
# # Analysing the column of **Hotel :-**
#
# * Mostly Which type of Hotel is prefered by customer.

# %%
# Hotel type and prefered Hotel type

# Visualization by the help of Pie Chart.

DF_1['hotel'].value_counts().plot.pie(explode=[0.05, 0.05],autopct='%1.1f%%', shadow=True, figsize=(6,8),fontsize=20)

plt.title('Pie Chart for Most Preffered  Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preffered  Hotel')

# %%
DF_1.hotel.value_counts()
# Out:
# City Hotel      53428
# Resort Hotel    33968
# Name: hotel, dtype: int64

# %% [markdown]
# Observations:-
# * City Hotel is most preferred hotel by guests. Thus city hotels has maximum bookings.

# %% [markdown]
# # Analysing data of hotel booking yearly & monthly :-
#
# 1. Value count of Babies, Adults & Childrens.

# %%
# Number of booking data contains babies.

DF_1.babies.value_counts()
# Out:
# 0     86482
# 1       897
# 2        15
# 10        1
# 9         1
# Name: babies, dtype: int64

# %%
# Number of booking contains adults.

DF_1.adults.value_counts()
# Out:
# 2     64497
# 1     16503
# 3      5935
# 0       385
# 4        60
# 26        5
# 27        2
# 20        2
# 5         2
# 40        1
# 50        1
# 55        1
# 6         1
# 10        1
# Name: adults, dtype: int64

# %%
# Number of booking contains childrens.

DF_1.children.value_counts()
# Out:
# 0.0     79032
# 1.0      4695
# 2.0      3593
# 3.0        75
# 10.0        1
# Name: children, dtype: int64

# %% [markdown]
# # Comparision of resort and city hotel booking yearly :-

# %%
# Set plot size.

plt.figure(figsize=(6,6))

# Plot with countplot.

sns.countplot(x=DF_1['arrival_date_year'],hue=DF_1['hotel'])
plt.title("Year Wise bookings")
# Out:
# Text(0.5, 1.0, 'Year Wise bookings')

# %%
DF_1.arrival_date_year.value_counts()
# Out:
# 2016    42391
# 2017    31692
# 2015    13313
# Name: arrival_date_year, dtype: int64

# %% [markdown]
# Observations:-
# * City Hotel is most preferred hotel by guests. Only in Quarter of 2015 has booking more than the resort hotel.

# %% [markdown]
# # Constructed the graph which shows number of reservations in monthly format :-
#
# * Presenting the data of monthly booking of Hotel on count plot .

# %%
# Set plot size and plot the line.

bookings_by_months_df=DF_1.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()

# Create month list.

months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# It will take the order of the month list in the df along with values.

bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)

# Sorting.

bookings_by_months_df
# Out:
#    arrival_date_month         hotel         adr
# 0               April    City Hotel  117.156250
# 1               April  Resort Hotel   79.283805
# 2              August    City Hotel  124.901601
# 3              August  Resort Hotel  187.566659
# 4            December    City Hotel   92.717339
# 5            December  Resort Hotel   65.409093
# 6            February    City Hotel   88.945304
# 7            February  Resort Hotel   54.081107
# 8             January    City Hotel   85.092612
# 9             January  Resort Hotel   49.131584
# 10               July    City Hotel  120.055385
# 11               July  Resort Hotel  156.166914
# 12               June    City Hotel  123.836342
# 13               June  Resort Hotel  112.340141
# 14              March    City Hotel   94.763375
# 15              March  Resort Hotel   57.569213
# 16                May    City Hotel  127.851240
# 17                May  Resort Hotel   80.551101
# 18           November    City Hotel   89.454120
# ...

# %%
# (rcparams = runtime configuration parameters)

plt.rcParams['figure.figsize'] = [25,7]
sns.set(style = 'white', font_scale = 1.5)

# plot.

Arrival = sns.countplot(df['arrival_date_year'], hue = 'arrival_date_month', data = df, palette = 'Set3',
             hue_order = ['January', 'February', 'March', 'April', 'May', 'June',
                          'July', 'August', 'September', 'October', 'November', 'December'])
Arrival.set(title = "Number of Reservations per year (months)")
plt.legend(loc='upper right');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Observations:-
# * Here we are analysed the booking in year 2015 starts from July to December.
# * The booking in 2016 is throughout the year i.e January to December.
# * The booking in 2017 is from January to August only.
# * October month has most of the booking.
#
#   **so** we have booking data of 6+12+8 = 26 months.

# %%
# show on map.
temp = DF_1['country'].value_counts().reset_index().rename(columns={'index':'country','country':'count'})
guest_map = px.choropleth(temp,
                          locations=temp['country'],
                          color=np.log(temp['count']), 
                          hover_name=temp['country'], 
                          color_continuous_scale=px.colors.sequential.Plasma,
                          title="Home country of guests")
guest_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Observations:-
# * People from all over the world are staying in these two types hotels. Most guests are from Portugal and other countries in Europe.

# %%
# Analysing the data of most preferred room type.

# Set plotsize.
plt.figure(figsize=(12,5))

# Plotting.
sns.countplot(x=DF_1['assigned_room_type'],order=DF_1['assigned_room_type'].value_counts().index) 

# Set x label for the plot.
plt.xlabel('Room Type')

# Set y label for the plot.
plt.ylabel('Count of Room Type')

# Set title for the plot.
plt.title("Most preferred Room type")
# Out:
# Text(0.5, 1.0, 'Most preferred Room type')

# %%
DF_1.assigned_room_type.value_counts()
# Out:
# A    46313
# D    22432
# E     7195
# F     3627
# G     2498
# C     2165
# B     1820
# H      706
# I      357
# K      276
# P        6
# L        1
# Name: assigned_room_type, dtype: int64

# %% [markdown]
# Observation:-
# * So the most preferred Room type is "A","D","E".

# %%
# Grouping all counts of market segment on the basis of hotel.

market_segment_df=DF_1[DF_1['is_canceled']==1]   # canceled=1
market_segment_df
market_segment_df=market_segment_df.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'counts'})   # group by

market_segment_df
# Out:
#    market_segment         hotel  counts
# 0        Aviation    City Hotel      45
# 1   Complementary    City Hotel      57
# 2   Complementary  Resort Hotel      31
# 3       Corporate    City Hotel     264
# 4       Corporate  Resort Hotel     246
# 5          Direct    City Hotel     912
# 6          Direct  Resort Hotel     825
# 7          Groups    City Hotel     890
# 8          Groups  Resort Hotel     445
# 9   Offline TA/TO    City Hotel    1261
# 10  Offline TA/TO  Resort Hotel     802
# 11      Online TA    City Hotel   12618
# 12      Online TA  Resort Hotel    5627
# 13      Undefined    City Hotel       2

# %%
# Set plotsize and plot barchart.

plt.figure(figsize=(12,8))
sns.barplot(x='market_segment',y='counts',hue="hotel",data= market_segment_df)

# set labels.

plt.xlabel('market_segment')
plt.ylabel('Counts')
plt.title('Cancellation Rate Vs market_segment')
# Out:
# Text(0.5, 1.0, 'Cancellation Rate Vs market_segment')

# %% [markdown]
# Observation:-
# * 'Online T/A' has the highest cancellation in both type of Hotels than the market segment.
# * In order to reduce the booking cancellations, hotels need to set the refundable/non-refundable and deposit policies.

# %%
# Top 10 agent that involved in most booking.

DF_1['agent'].value_counts().head(10)
# Out:
# 9.0      28759
# 240.0    13028
# 0.0      12193
# 14.0      3349
# 7.0       3300
# 250.0     2779
# 241.0     1644
# 28.0      1502
# 8.0       1383
# 1.0       1232
# Name: agent, dtype: int64

# %%
# Return highest bookings made by agents.
highest_bookings= DF_1.groupby(['agent'])['agent'].agg({'count'}).reset_index().rename(columns={'count': "Most_Bookings" }).sort_values(by='Most_Bookings',ascending=False)

 # As agent 0 was NAN value and we replaced it with 0 and indicates no bookings.so droping.
highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index,inplace=True) 

# Taking top 10 bookings made by agent.
top_ten_highest_bookings=highest_bookings[:10]

top_ten_highest_bookings
# Out:
#      agent  Most_Bookings
# 9      9.0          28759
# 174  240.0          13028
# 14    14.0           3349
# 7      7.0           3300
# 183  250.0           2779
# 175  241.0           1644
# 27    28.0           1502
# 8      8.0           1383
# 1      1.0           1232
# 6      6.0           1117

# %%
# Number of bookings made by each agent.

plt.figure(figsize=(12,8))
sns.barplot(x=top_ten_highest_bookings['agent'],y=top_ten_highest_bookings['Most_Bookings'],order=top_ten_highest_bookings['agent'])
plt.xlabel('Agent No')
plt.ylabel('Number of Bookings')
plt.title("Most Bookings Made by the agent")
# Out:
# Text(0.5, 1.0, 'Most Bookings Made by the agent')

# %% [markdown]
# Observation:-
# * Agent ID no: 9 made heighest number of the bookings.

# %%
# Counting the number of guests from top 10 countries.

country_df=DF_1['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]

# Visualizing by plotting the graph.

plt.figure(figsize=(12,8))
sns.barplot(x=country_df['country'],y=country_df['count of guests'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=20)
plt.plot()
# Out:
# []

# %% [markdown]
# Observations:-
# * Most of the guests are coming from portugal i.e more 25000 guests are from portugal
# abbrevations for countries-
#
# * PRT - Portugal
# * GBR - United Kingdom
# * FRA - France
# * ESP - Spain
# * DEU - Germany
# * ITA - Itlay
# * IRL - Ireland
# * BEL - Belgium
# * BRA - Brazil
# * NLD - Netherlands

# %%
# Customer type.

DF_1['customer_type'].value_counts().plot.pie(explode=[0.05]*4,shadow=True,autopct='%1.1f%%',figsize=(6,8),fontsize=15,labels=None)

labels=DF_1['customer_type'].value_counts().index.tolist()
plt.title('% Distribution of Customer Type')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %%
DF_1.customer_type.value_counts()
# Out:
# Transient          71986
# Transient-Party    11727
# Contract            3139
# Group                544
# Name: customer_type, dtype: int64

# %% [markdown]
# Observation:-
# * Transient customer type is more which is 82.4 %. percentage of Booking associated by the Group is vey low.

# %%
# Customer repetation. ('1'. Shows the values of repeated customers)

DF_1.is_repeated_guest.value_counts()
# Out:
# 0    83981
# 1     3415
# Name: is_repeated_guest, dtype: int64

# %%
# Percentage of cancellation of booking.

# Which country has max value of cancellation of booking.

DF_1['is_canceled'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(6,8),fontsize=20)
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %%
DF_1.is_canceled.value_counts()
# Out:
# 0    63371
# 1    24025
# Name: is_canceled, dtype: int64

# %% [markdown]
# Observation:-
# * 0 = Not cancelled.
# * 1 = Cancelled.
# * 27.5 % of the bookings was cancelled.

# %%
# Booking cancellation difference between City and Resort hotel.

# Booking cancelled = 1.
# Booking not cancelled = 0.

# Creating new DataFrame where bookings are cancelled.
canceled_df=DF_1[DF_1['is_canceled']==1]

# Grouping by hotel.
canceled_df=canceled_df.groupby('hotel').size().reset_index().rename(columns={0: "no_of_cancelled_bookings"})

# Adding 'total booking column for calculating the percentage.
canceled_df['total_bookings']=DF_1.groupby('hotel').size().reset_index().rename(columns={0:"total_bookings"}).drop('hotel',axis=1)
canceled_df

# Plotting the barchat.
plt.figure(figsize=(4,6))
sns.barplot(x=canceled_df['hotel'],y=canceled_df['no_of_cancelled_bookings']*100/canceled_df['total_bookings'])

# set labels.
plt.xlabel('Hotel type')
plt.ylabel('Percentage(%)')
plt.title("Percentage of booking cancellation")
# Out:
# Text(0.5, 1.0, 'Percentage of booking cancellation')

# %% [markdown]
# Observations:-
# * Booking cancellation rate is high for City hotels, which almost 30 % average lead time for resort.

# %%
# Percentage distribution of Deposite type

DF_1['deposit_type'].value_counts().plot.pie(explode=(0.5,0.5,0.05),autopct='%1.1f%%',shadow=False,figsize=(6,8),fontsize=20,labels=None)
plt.title("% Distribution of deposit type")
labels=DF_1['deposit_type'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %%
DF_1.deposit_type.value_counts()
# Out:
# No Deposit    86251
# Non Refund     1038
# Refundable      107
# Name: deposit_type, dtype: int64

# %% [markdown]
# Observation:-
# * 98.7 % of the guests prefer "No deposit" type of deposit.

# %%
# Arrival status of customer in hotel.

plt.rcParams['figure.figsize'] = [5,5]
sns.set(style = 'darkgrid', font_scale = 1.2)

# Catplot. (countplot)

cat = sns.catplot(x = 'reservation_status', col = 'arrival_date_year', kind = 'count', data = df,
            height = 6, palette = ['Blue', 'mediumaquamarine', 'Orange']);

# %%
# Requirement of pariking facilities.

DF_1['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%',shadow=False,figsize=(6,8),fontsize=15,labels=None)
labels=DF_1['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# Observation:-
# * 91.6 % guests did not required the parking space. only 8.3 % guests required only 1 parking space.

# %%
# Preferred meal type of customer.

plt.figure(figsize=(6,6))
sns.countplot(x=DF_1['meal'])
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %%
DF_1.meal.value_counts()
# Out:
# BB           67978
# SC            9481
# HB            9085
# Undefined      492
# FB             360
# Name: meal, dtype: int64

# %% [markdown]
# Observation:-
# * So the most preferred meal type by the guests is BB( Bed and Breakfast)
# * HB- (Half Board)
# * FB- (Full Board)
# * SC- (Self Catering)

# %%
# Stays in week nignts and weekend nights. 

DF_1['stays_in_weekend_nights'].value_counts()
# Out:
# 0     35151
# 2     26414
# 1     22657
# 4      1734
# 3      1150
# 6       113
# 5        70
# 8        60
# 7        15
# 9        10
# 10        7
# 12        5
# 13        3
# 16        3
# 14        2
# 18        1
# 19        1
# Name: stays_in_weekend_nights, dtype: int64

# %%
DF_1['stays_in_week_nights'].value_counts()
# Out:
# 1     22191
# 2     20744
# 3     16259
# 5      9663
# 4      7874
# 0      6175
# 6      1379
# 10      972
# 7       967
# 8       613
# 9       219
# 15       68
# 11       50
# 20       41
# 12       40
# 13       27
# 14       25
# 19       21
# 21       15
# 16       13
# 22        7
# 25        6
# 18        6
# 30        5
# 17        4
# 24        2
# 40        2
# 33        1
# 42        1
# 50        1
# 32        1
# 26        1
# 34        1
# 35        1
# 41        1
# Name: stays_in_week_nights, dtype: int64

# %%
# Addition of stays in weeknights and weekend nights.

DF_1['stays'] = DF_1['stays_in_week_nights'] + DF_1['stays_in_weekend_nights']
DF_1['stays']
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         2
#          ..
# 119385    7
# 119386    7
# 119387    7
# 119388    7
# 119389    9
# Name: stays, Length: 87396, dtype: int64

# %%
# Graphical representation of booking stays of in week nights and weekend nights.

plt.figure(figsize= (20,8))
sns.countplot(DF_1[DF_1['stays'] != 0]['stays'], facecolor='green')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
# Set plot size and plot the line.(Graphical representation of ADR)

plt.figure(figsize=(18,6))
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['adr'],hue=bookings_by_months_df['hotel'])

# Set lables.

plt.title('ADR across each month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# Observation:-
# * For Resort hotel is ADR is high in the months June, July, August as compared to City Hotels. May be Customers/People wants to spend their Summer vacation in Resorts Hotels.
# * The best time for guests to visit Resort or City hotels is January, February, March, April,October, November and December, as the average daily rate in this month is very low.

# %% [markdown]
# After analysing data of repeated customer we calculate the number of repeated customer and that is 3415.

# %% [markdown]
# # Conclusion:-
#
# * City hotels are the most preferred hotel type by the guests. We can say City  hotel is the busiest hotel.
#
# * Most of the bookings for City hotels and Resort hotel were happened in 2016.
#
# * Resort hotels have the most repeated guests.
#
# * October month has most of the bookings.
#
# * The most preferred Room type by customer is "A","D","E", etc.
#
# * 'Online T/A' has the highest cancellation in both type of Hotels.
# In order to reduce the booking cancellations, hotels need to set the refundable/non-refundable and deposit policies.
#
# * Maximum number of guests were from Portugal, i.e. more than 25000 guests.
#
# * Transient customer type is more which is 82.4 %. percentage of Booking associated by the Group is vey low.
#
# * Among all the bookings made by customer. 27.5 % of the bookings were cancelled.
#
# * Booking cancellation rate is high for City hotels which almost 30 %.
# Average lead time for resort hotel is high.
#
# * From the total bookings there are  98.7 % of the guests prefer "No deposit" type of deposit.
#
# * Most of the customers (91.6%) do not require car parking spaces.
#
# * BB(Bed & Breakfast) is the most preferred type of meal by the guests.
#
# * Optimal stay in both the type hotel is less than 7 days. Usually people stay for a week.
#
# * Almost 72.5 % people did not cancel their bookings even after not getting the same room which they reserved while booking hotel.
#
# * Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
